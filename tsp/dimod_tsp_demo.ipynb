# %%
# %pip install dwave-system
# Out:
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ----------------------------------- ---- 1.0/1.2 MB 25.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 3.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------------- -------------- 1.0/1.6 MB 49.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 21.7 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# ...
#    ---------------------------------------- 0.0/837.6 kB ? eta -:--:--
#    --------------------------------------- 837.6/837.6 kB 18.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
# ...

# %%
import numpy as np
from dimod import BinaryQuadraticModel, BINARY
from dwave.system import DWaveSampler, EmbeddingComposite, LeapHybridSampler
import matplotlib.pyplot as plt
from dimod_tsp import TSPDimod
from dimod_tsp import *

# %%
tsp, result = run_tsp_example()
    
# Visualize the solution
if result['is_valid']:
        positions = {
            0: (0.2, 0.8),  # New York
            1: (0.3, 0.9),  # Boston  
            2: (0.1, 0.4),  # Chicago
            3: (0.7, 0.1)   # Miami
        }
        tsp.visualize_tour(result['tour'], positions)
else:
        print("Solution has constraint violations - check parameters or increase constraint strength")
# Out:
# Creating TSP instance...
# Formulating as BQM...
# BQM created with 16 variables and 96 quadratic terms
#
# Solving with classical simulated annealing...
# ...
# TSP SOLUTION DETAILS
# ...
# Tour: ['New York', 'Chicago', 'Miami', 'Boston']
# Distance: 80.00
# Energy: -2160.00
# Valid Tour: True
# Constraint Violations:
#   - City constraints: 0
#   - Position constraints: 0
# ...
